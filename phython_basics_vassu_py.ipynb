# %%
name="Vassu"
age=30
hight=5.10
student=True
print("Name:",name, "Age:", age, "Hight", hight, "Student:",student)
# Out:
# Name: Vassu Age: 30 Hight 5.1 Student: True

# %%
print(f"Name:{name} | Age:{age}  | Hight:{hight} | Student:{student}")
# Out:
# Name:Vassu | Age:30  | Hight:5.1 | Student:True

# %%
months=age*12
days=age*365
remainder=age%7
raised=age**2
print(f"My age in Months:{months} | Days:{days}  | Remainder:{remainder} | Raised:{raised}")
# Out:
# My age in Months:360 | Days:10950  | Remainder:2 | Raised:900
